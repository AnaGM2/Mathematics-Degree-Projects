# %%
pip install jupyter_contrib_nbextensions
# Out:
# ...
#   Using cached jupyter_contrib_nbextensions-0.5.1-py2.py3-none-any.whl (20.9 MB)
# ...
#      |████████████████████████████████| 4.5 MB 2.2 MB/s eta 0:00:01     |███████▌                        | 1.1 MB 2.2 MB/s eta 0:00:02
# ...
#   Using cached jupyter_latex_envs-1.4.6-py2.py3-none-any.whl
# ...
#   Using cached jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge jupyter_contrib_nbextensions
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/anaconda3
#
#   added / updated specs:
#     - jupyter_contrib_nbextensions
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jupyter_contrib_nbextensions-0.5.1|     pyhd8ed1ab_2        19.5 MB  conda-forge
#     jupyter_highlight_selected_word-0.2.0|py38h50d1736_1002          14 KB  conda-forge
#     jupyter_latex_envs-1.4.6   |  pyhd8ed1ab_1002         735 KB  conda-forge
#     lxml-4.6.4                 |   py38h6ea4786_0         1.3 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        21.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   jupyter_contrib_n~ conda-forge/noarch::jupyter_contrib_nbextensions-0.5.1-pyhd8ed1ab_2
# ...
